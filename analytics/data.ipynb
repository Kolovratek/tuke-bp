# %%
import pandas as pd

df = pd.read_csv(r'./dataset.csv')
print(df)
# Out:
#        id  firstname  lastname                       email  \
# 0     100    Kamilah    Goerke  Kamilah.Goerke@yopmail.com
# 1     101    Jennica       Nea     Jennica.Nea@yopmail.com
# 2     102     Trudie    Wandie   Trudie.Wandie@yopmail.com
# 3     103       Amii     Levey      Amii.Levey@yopmail.com
# 4     104      Sonni    Ephrem    Sonni.Ephrem@yopmail.com
# ..    ...        ...       ...                         ...
# 995  1095     Myriam    Allina   Myriam.Allina@yopmail.com
# 996  1096  Constance      Ries  Constance.Ries@yopmail.com
# 997  1097     Frieda     Stevy    Frieda.Stevy@yopmail.com
# 998  1098       Rori     Brady      Rori.Brady@yopmail.com
# 999  1099      Candi  Ralfston  Candi.Ralfston@yopmail.com
#
#                        email2      profession  Field Name
# 0    Kamilah.Goerke@gmail.com  police officer           1
# 1       Jennica.Nea@gmail.com       developer           2
# 2     Trudie.Wandie@gmail.com          worker           3
# ...

# %% [markdown]
# ## TEST

# %%
df.describe(include='all')
# Out:
#                  id firstname lastname                       email  \
# count   1000.000000      1000     1000                        1000
# unique          NaN       536      661                        1000
# top             NaN   Damaris   Merell  Kamilah.Goerke@yopmail.com
# freq            NaN         6        6                           1
# mean     599.500000       NaN      NaN                         NaN
# std      288.819436       NaN      NaN                         NaN
# min      100.000000       NaN      NaN                         NaN
# 25%      349.750000       NaN      NaN                         NaN
# 50%      599.500000       NaN      NaN                         NaN
# 75%      849.250000       NaN      NaN                         NaN
# max     1099.000000       NaN      NaN                         NaN
#
#                           email2 profession   Field Name
# count                       1000       1000  1000.000000
# ...

# %%
df.shape
# Out:
# (1000, 7)
